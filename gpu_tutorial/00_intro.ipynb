# %% [markdown]
# <table>
#  <tr align=left><td><img align=left src="https://i.creativecommons.org/l/by/4.0/88x31.png">
#  <td>Text provided under a Creative Commons Attribution license, CC-BY. All code is made available under the FSF-approved MIT license. (c) Kyle T. Mandli</td>
# </table>

# %% [markdown]
# # RESCUER Workshop 4 - GPU Computing Tutorial

# %% [markdown]
# ## Who am I?
#
# **Kyle Mandli** - **NSF-NCAR** Scientist
#
# National Science Foundation - National Center for Atmospheric Research - CGD Lab
#
# **Research**
# - Computational mathematics with applications to coastal floods and other geophysical hazards
#     - Numerical methods for hyperbolic PDE
#     - Algorithms for high performance computing
#     - Software development practices in scientific and engineering software
# - Climate change and coastal flood hazards
#     - Measuring uncertainty in coastal flood hazards
#     - Change in risk due to climate change
#
# **Contact**
# https://kylemandli.com<br>
# <kmandli@ucar.edu><br>
# <kmandli@flatironinstitute.org>

# %% [markdown]
# ## Plan
#
# **Me Talking At You**
# 1. Introduction/Review of Computer Architecture and Parallel Computing
# 2. GPU Computing Components (CuPy)
#
# **Hands-On**
# 1. OpenACC?
# 2. GPU computing using CuPy
